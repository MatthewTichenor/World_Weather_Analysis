# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID         City Country                 Date    Lat     Lng  Max Temp  \
# 0        0      Kahului      US  2020-07-12 05:10:48  20.89 -156.47     82.40
# 1        1  Oktyabrskiy      RU  2020-07-12 05:15:23  54.48   53.47     71.11
# 2        2   Butaritari      KI  2020-07-12 05:10:37   3.07  172.79     82.92
# 3        3    Jamestown      US  2020-07-12 05:10:26  42.10  -79.24     66.99
# 4        4       Avarua      CK  2020-07-12 05:10:19 -21.21 -159.78     73.40
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        58          40       20.80    scattered clouds
# 1        74           1        8.79           clear sky
# 2        79          79       14.43          light rain
# 3        93           1       10.29           clear sky
# 4        83          99        3.36          light rain
#
#    Rain inches (last 1 hours)  Snow inches (last 1 hours)
# 0                        0.00                           0
# ...

# %%
# Prompt the customer for the minimum temperature preference.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
# Prompt the customer for the maximum temperature preference. 
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Prompt the customer to answer if he or she would like it to be raining or not.
rain = str(input('Do you want it to be raining? (yes/no)\n'))
# Prompt the customer to answer if he or she would like it to be snowing or not
snow = str(input('Do you want it to be snowing? (yes/no)\n'))
# Out:
# What is the minimum temperature you would like for your trip? 50
# What is the maximum temperature you would like for your trip? 90
# Do you want it to be raining? (yes/no)
# yes
# Do you want it to be snowing? (yes/no)
# no

# %%
# Filter the dataset to find the cities that fit the criteria.
for index, row in city_data_df.iterrows():
    if rain == "no":
        rain_inches = city_data_df["Rain inches (last 1 hours)"] == 0
    else:
        rain_inches = city_data_df["Rain inches (last 1 hours)"] != 0
    if snow == "no":
        snow_inches = city_data_df["Snow inches (last 1 hours)"] == 0
    else:
        snow_inches = city_data_df["Snow inches (last 1 hours)"] != 0

# %%
# Filter the dataset to find the cities that fit the criteria.

preferred_cities_df = city_data_df.loc[(city_data_df["Rain inches (last 1 hours)"] != rain_inches) &
                                       (city_data_df["Snow inches (last 1 hours)"] != snow_inches) &
                                       (city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
                                       
preferred_cities_df.head(10)
# Out:
#     City_ID        City Country                 Date    Lat     Lng  Max Temp  \
# 2         2  Butaritari      KI  2020-07-12 05:10:37   3.07  172.79     82.92
# 4         4      Avarua      CK  2020-07-12 05:10:19 -21.21 -159.78     73.40
# 19       19    Junagarh      IN  2020-07-12 05:15:27  19.87   82.93     89.38
# 20       20    Cabedelo      BR  2020-07-12 05:15:27  -6.98  -34.83     74.86
# 22       22     Sorland      NO  2020-07-12 05:15:28  67.67   12.69     51.62
# 32       32   Joshimath      IN  2020-07-12 05:15:29  30.57   79.57     73.40
# 35       35        Hilo      US  2020-07-12 05:08:09  19.73 -155.09     75.20
# 36       36      Carmen      MX  2020-07-12 05:11:49  18.63  -91.83     83.61
# 42       42      Sorong      ID  2020-07-12 05:15:30  -0.88  131.25     76.95
# 46       46    Lorengau      PG  2020-07-12 05:11:25  -2.02  147.27     82.58
#
#     Humidity  Cloudiness  Wind Speed Current Description  \
# ...

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(20)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 2       Butaritari      KI     82.92          light rain   3.07  172.79
# 4           Avarua      CK     73.40          light rain -21.21 -159.78
# 19        Junagarh      IN     89.38          light rain  19.87   82.93
# 20        Cabedelo      BR     74.86          light rain  -6.98  -34.83
# 22         Sorland      NO     51.62          light rain  67.67   12.69
# 32       Joshimath      IN     73.40          light rain  30.57   79.57
# 35            Hilo      US     75.20          light rain  19.73 -155.09
# 36          Carmen      MX     83.61          light rain  18.63  -91.83
# 42          Sorong      ID     76.95       moderate rain  -0.88  131.25
# 46        Lorengau      PG     82.58       moderate rain  -2.02  147.27
# 69         Arkhara      RU     81.66          light rain  49.42  130.08
# 70          Atuona      PF     79.81          light rain  -9.80 -139.03
# ...

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to the params dictionary as values to the location key.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
hotel_df.to_csv(output_data_file, index_label="City_ID")
