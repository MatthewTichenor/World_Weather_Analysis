# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date    Lat     Lng  \
# 0        0        Penzance      GB  2020-07-12 16:38:01  50.12   -5.54
# 1        1          Hobart      AU  2020-07-12 16:37:59 -42.88  147.33
# 2        2       Busselton      AU  2020-07-12 16:38:21 -33.65  115.33
# 3        3  Severo-Kurilsk      RU  2020-07-12 16:38:22  50.68  156.12
# 4        4    Saint George      US  2020-07-12 16:36:14  37.10 -113.58
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 0     66.99        59          41        9.17    scattered clouds
# 1     39.00        93          90       10.29     overcast clouds
# 2     57.00        80          49       15.30    scattered clouds
# 3     49.50        92         100       10.09     overcast clouds
# 4     93.99        21           1        4.70           clear sky
#
#    Rain inches (last 1 hours)  Snow inches (last 1 hours)
# 0                         0.0                           0
# ...

# %%
# Prompt the customer for the minimum temperature preference.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
# Prompt the customer for the maximum temperature preference. 
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Prompt the customer to answer if he or she would like it to be raining or not.
rain = str(input('Do you want it to be raining? (yes/no)\n'))
# Prompt the customer to answer if he or she would like it to be snowing or not
snow = str(input('Do you want it to be snowing? (yes/no)\n'))
# Out:
# What is the minimum temperature you would like for your trip? 50
# What is the maximum temperature you would like for your trip? 90
# Do you want it to be raining? (yes/no)
# yes
# Do you want it to be snowing? (yes/no)
# no

# %%
# Filter the dataset to find the cities that fit the criteria.
for index, row in city_data_df.iterrows():
    if rain == "no":
        rain_inches = city_data_df["Rain inches (last 1 hours)"] == 0
    else:
        rain_inches = city_data_df["Rain inches (last 1 hours)"] != 0
    if snow == "no":
        snow_inches = city_data_df["Snow inches (last 1 hours)"] == 0
    else:
        snow_inches = city_data_df["Snow inches (last 1 hours)"] != 0

# %%
# Filter the dataset to find the cities that fit the criteria.

preferred_cities_df = city_data_df.loc[(city_data_df["Rain inches (last 1 hours)"] != rain_inches) &
                                       (city_data_df["Snow inches (last 1 hours)"] != snow_inches) &
                                       (city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
                                       
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 10       10     Dicabisagan      PH  2020-07-12 16:38:22  17.08  122.42
# 12       12   Sholokhovskiy      RU  2020-07-12 16:38:22  48.28   41.05
# 43       43          Amahai      ID  2020-07-12 16:38:26  -3.33  128.92
# 66       66           Baoro      CF  2020-07-12 16:38:29   5.67   15.97
# 71       71            Zhob      PK  2020-07-12 16:38:30  31.34   69.45
# 78       78  Saint-Philippe      RE  2020-07-12 16:38:31 -21.36   55.77
# 85       85           Coari      BR  2020-07-12 16:38:32  -4.08  -63.14
# 86       86          Marawi      PH  2020-07-12 16:38:32   8.00  124.29
# 89       89          Kiunga      PG  2020-07-12 16:38:33  -6.12  141.29
# 99       99          Vanimo      PG  2020-07-12 16:38:34  -2.67  141.30
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 10     79.74        82         100        3.58          light rain
# ...

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 10     Dicabisagan      PH     79.74          light rain  17.08  122.42
# 12   Sholokhovskiy      RU     76.08          light rain  48.28   41.05
# 43          Amahai      ID     77.29          light rain  -3.33  128.92
# 66           Baoro      CF     73.76          light rain   5.67   15.97
# 71            Zhob      PK     75.76       moderate rain  31.34   69.45
# 78  Saint-Philippe      RE     69.80          light rain -21.36   55.77
# 85           Coari      BR     84.16          light rain  -4.08  -63.14
# 86          Marawi      PH     75.99          light rain   8.00  124.29
# 89          Kiunga      PG     72.45       moderate rain  -6.12  141.29
# 99          Vanimo      PG     78.46          light rain  -2.67  141.30
#
#    Hotel Name
# 10
# 12
# 43
# 66
# 71
# 78
# 85
# 86
# 89
# 99

# %%
# Dependencies and Setup
import requests
import gmaps


# Import API key
from config import g_key

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to the params dictionary as values to the location key.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 10       10     Dicabisagan      PH  2020-07-12 16:38:22  17.08  122.42
# 12       12   Sholokhovskiy      RU  2020-07-12 16:38:22  48.28   41.05
# 43       43          Amahai      ID  2020-07-12 16:38:26  -3.33  128.92
# 66       66           Baoro      CF  2020-07-12 16:38:29   5.67   15.97
# 71       71            Zhob      PK  2020-07-12 16:38:30  31.34   69.45
# 78       78  Saint-Philippe      RE  2020-07-12 16:38:31 -21.36   55.77
# 85       85           Coari      BR  2020-07-12 16:38:32  -4.08  -63.14
# 86       86          Marawi      PH  2020-07-12 16:38:32   8.00  124.29
# 89       89          Kiunga      PG  2020-07-12 16:38:33  -6.12  141.29
# 99       99          Vanimo      PG  2020-07-12 16:38:34  -2.67  141.30
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 10     79.74        82         100        3.58          light rain
# ...

# %%
Baoro = preferred_cities_df[preferred_cities_df['City'].str.contains("Baoro")]
Baoro
# Out:
#     City_ID   City Country                 Date   Lat    Lng  Max Temp  \
# 66       66  Baoro      CF  2020-07-12 16:38:29  5.67  15.97     73.76
#
#     Humidity  Cloudiness  Wind Speed Current Description  \
# 66        87          57        2.93          light rain
#
#     Rain inches (last 1 hours)  Snow inches (last 1 hours)
# 66                        0.29                           0

# %%
Zhob = preferred_cities_df[preferred_cities_df['City'].str.contains("Zhob")]
Zhob
# Out:
#     City_ID  City Country                 Date    Lat    Lng  Max Temp  \
# 71       71  Zhob      PK  2020-07-12 16:38:30  31.34  69.45     75.76
#
#     Humidity  Cloudiness  Wind Speed Current Description  \
# 71        50          20        8.57       moderate rain
#
#     Rain inches (last 1 hours)  Snow inches (last 1 hours)
# 71                        1.11                           0

# %%
Marawi = preferred_cities_df[preferred_cities_df['City'].str.contains("Marawi")]
Marawi
# Out:
#     City_ID    City Country                 Date  Lat     Lng  Max Temp  \
# 86       86  Marawi      PH  2020-07-12 16:38:32  8.0  124.29     75.99
#
#     Humidity  Cloudiness  Wind Speed Current Description  \
# 86        87          99         7.0          light rain
#
#     Rain inches (last 1 hours)  Snow inches (last 1 hours)
# 86                        0.63                           0

# %%
Vanimo = preferred_cities_df[preferred_cities_df['City'].str.contains("Vanimo")]
Vanimo
# Out:
#     City_ID    City Country                 Date   Lat    Lng  Max Temp  \
# 99       99  Vanimo      PG  2020-07-12 16:38:34 -2.67  141.3     78.46
#
#     Humidity  Cloudiness  Wind Speed Current Description  \
# 99        80          99        0.96          light rain
#
#     Rain inches (last 1 hours)  Snow inches (last 1 hours)
# 99                        0.41                           0

# %%
four_cities = pd.concat([Baoro,Zhob,Marawi,Vanimo])
four_cities
# Out:
#     City_ID    City Country                 Date    Lat     Lng  Max Temp  \
# 66       66   Baoro      CF  2020-07-12 16:38:29   5.67   15.97     73.76
# 71       71    Zhob      PK  2020-07-12 16:38:30  31.34   69.45     75.76
# 86       86  Marawi      PH  2020-07-12 16:38:32   8.00  124.29     75.99
# 99       99  Vanimo      PG  2020-07-12 16:38:34  -2.67  141.30     78.46
#
#     Humidity  Cloudiness  Wind Speed Current Description  \
# 66        87          57        2.93          light rain
# 71        50          20        8.57       moderate rain
# 86        87          99        7.00          light rain
# 99        80          99        0.96          light rain
#
#     Rain inches (last 1 hours)  Snow inches (last 1 hours)
# 66                        0.29                           0
# 71                        1.11                           0
# 86                        0.63                           0
# 99                        0.41                           0

# %%
columnsData = four_cities.loc[:,['City','Lat','Lng']]
columnsData
# Out:
#       City    Lat     Lng
# 66   Baoro   5.67   15.97
# 71    Zhob  31.34   69.45
# 86  Marawi   8.00  124.29
# 99  Vanimo  -2.67  141.30

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key= "g_key")

# Latitude-longitude pairs
Baoro= (5.67, 15.97)
Zhob = (31.34, 69.45)
Marawi = (8.00, 124.29)
Vanimo = (-2.67, 141.30)

fig = gmaps.figure()
Pic = gmaps.directions_layer(Baoro, Zhob , waypoints=[Marawi, Vanimo])
fig.add_layer(Pic)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
Pic_via_driving = gmaps.directions_layer(
        Baoro, Zhob, waypoints=[Marawi, Vanimo],  
        travel_mode='DRIVING')
fig.add_layer(Pic_via_driving)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
four_cities
# Out:
#     City_ID    City Country                 Date    Lat     Lng  Max Temp  \
# 66       66   Baoro      CF  2020-07-12 16:38:29   5.67   15.97     73.76
# 71       71    Zhob      PK  2020-07-12 16:38:30  31.34   69.45     75.76
# 86       86  Marawi      PH  2020-07-12 16:38:32   8.00  124.29     75.99
# 99       99  Vanimo      PG  2020-07-12 16:38:34  -2.67  141.30     78.46
#
#     Humidity  Cloudiness  Wind Speed Current Description  \
# 66        87          57        2.93          light rain
# 71        50          20        8.57       moderate rain
# 86        87          99        7.00          light rain
# 99        80          99        0.96          light rain
#
#     Rain inches (last 1 hours)  Snow inches (last 1 hours)
# 66                        0.29                           0
# 71                        1.11                           0
# 86                        0.63                           0
# 99                        0.41                           0

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
# Iterate through the DataFrame.
for index, row in four_cities.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to the params dictionary as values to the location key.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
four_cities_hotel_info = [info_box_template.format(**row) for index, row in four_cities.iterrows()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-64255d11060c> in <module>
#       9 """
#      10 # Store the DataFrame Row.
# ---> 11 four_cities_hotel_info = [info_box_template.format(**row) for index, row in four_cities.iterrows()]
#
# <ipython-input-25-64255d11060c> in <listcomp>(.0)
#       9 """
#      10 # Store the DataFrame Row.
# ---> 11 four_cities_hotel_info = [info_box_template.format(**row) for index, row in four_cities.iterrows()]
#
# KeyError: 'Hotel Name'

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = four_cities[["Lat", "Lng"]]
max_temp = four_cities["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=four_cities_hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-3923298ae498> in <module>
#       5 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
#       6              max_intensity=300, point_radius=4)
# ----> 7 marker_layer = gmaps.marker_layer(locations, info_box_content=four_cities_hotel_info)
#       8 fig.add_layer(heat_layer)
#       9 fig.add_layer(marker_layer)
#
# NameError: name 'four_cities_hotel_info' is not defined
